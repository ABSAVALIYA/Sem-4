# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Python Programming - 2301CS404</b></center>
# <center><b><h1>Lab - 2</b></center>
# <pre>

# %%
Name : Avinash B. Savaliya
23010101246
# Out:
#   Cell In[1], line 1
#     Name : Avinash B. Savaliya
#                    ^
# SyntaxError: invalid syntax

# %% [markdown]
# # if..else..

# %% [markdown]
# ### 01) WAP to check whether the given number is positive or negative.

# %%
number = int(input("Enter a number: "))
if number >= 0:
    print(str(number) + " is positive")
else:
    print(str(number) + " is negative")

# %% [markdown]
# ### 02) WAP to check whether the given number is odd or even.

# %%
number = int(input("Enter a number: "))
if number % 2 == 0:
    print(str(number) + " is even")
else:
    print(str(number) + " is odd")

# %% [markdown]
# ### 03) WAP to find out largest number from given two numbers using simple if and ternary operator.

# %%
number1 = int(input("Enter first number: "))
number2 = int(input("Enter second number: "))
print(str(number1) + " is larger") if number1 > number2 else print(str(number2) + " is larger")

# %% [markdown]
# ### 04) WAP to find out largest number from given three numbers.

# %%
number1 = int(input("Enter first number: "))
number2 = int(input("Enter second number: "))
number3 = int(input("Enter third number: "))

if number1 > number2:
    if number1 > number3:
        print(str(number1) + " is largest")
    else:
        print(str(number3) + " is largest")
else:
    if number2 > number3:
        print(str(number2) + " is largest")
    else:
        print(str(number3) + " is largest")

# %% [markdown]
# ### 05) WAP to check whether the given year is leap year or not.
# [If a year can be divisible by 4 but not divisible by 100 then it is leap year but if it is divisible by 400 then it is leap year]

# %%
year = int(input("Enter a year: "))

if year % 4 == 0:
    if year % 400 == 0 :
        print(str(year) + "is leap year")
    elif year % 100 == 0:
        print(str(year) + " is not leap year")
    else:
        print(str(year) + " is leap year")
else:
    print(str(year) + " is not leap year")

# %% [markdown]
# ### 06) WAP in python to display the name of the day according to the number given by the user.

# %%
dayNumber = int(input("Enter a number: "))
if dayNumber <= 0 or dayNumber > 7:
    print("Invalid Input")
elif dayNumber == 1:
    print("Hello it's sunday")
elif dayNumber == 2:
    print("Hello it's monday")
elif dayNumber == 3:
    print("Hello it's tuesday")
elif dayNumber == 4:
    print("Hello it's wednesday")
elif dayNumber == 5:
    print("Hello it's thursday")
elif dayNumber == 6:
    print("Hello it's friday")
elif dayNumber == 7:
    print("Hello it's saturday")

# %% [markdown]
# ### 07) WAP to implement simple calculator which performs (add,sub,mul,div) of two no. based on user input.

# %%
number1 = int(input("Enter number 1: "))
number2 = int(input("Enter number 2: "))

print("Enter 1 to add")
print("Enter 2 to subtract")
print("Enter 3 to multiply")
print("Enter 4 to devide")

sign = int(input("Enter sign: "))

if sign == 1:
    print(str(number1) + " + " + str(number2) + " = " + str(number1 + number2))
elif sign == 2:
    print(str(number1) + " - " + str(number2) + " = " + str(number1 - number2))
elif sign == 3:
    print(str(number1) + " * " + str(number2) + " = " + str(number1 * number2))
elif sign == 4:
    print(str(number1) + " / " + str(number2) + " = " + str(number1 // number2))

# %% [markdown]
# ### 08) WAP to read marks of five subjects. Calculate percentage and print class accordingly.
# Fail below 35 </br>
# Pass Class between 35 to 45 </br>
# Second Class</br>
# between 45 to 60</br>
# First Class between 60 to 70</br>
# Distinction if more than 70

# %%
subject1 = int(input("Enter physics marks: "))
subject2 = int(input("Enter chemistry marks: "))
subject3 = int(input("Enter mathematics marks: "))
subject4 = int(input("Enter biology marks: "))
subject5 = int(input("Enter english marks: "))

totalMarks = subject1 + subject2 + subject3 + subject4 + subject5
percentage = totalMarks * 100 / 500

print(str(percentage) + "%")

if percentage > 70:
    print("Distinction")
elif percentage <= 70 and percentage > 60:
    print("First Class")
elif percentage <= 60 and percentage > 45:
    print("second Class")
elif percentage <= 45 and percentage > 35:
    print("Pass Class")
elif percentage < 35 :
    print("Congratulations!! You are failed...")

# %% [markdown]
# ### 09) Three sides of a triangle are entered through the keyboard, WAP to check whether the triangle is isosceles, equilateral, scalene or right-angled triangle.

# %%
side1 = int(input("Enter side 1: "))
side2 = int(input("Enter side 2: "))
side3 = int(input("Enter side 3: "))

if side1 == side2 == side3:
    print("Equilateral triangle")
elif side1 == side2 or side2 == side3 or side1 == side3:
    print("Isosceles tringle")
elif ((side1 * side1) + (side2 * side2) == (side3 * side3) or
      (side3 * side3) + (side2 * side2) == (side1 * side1) or
      (side1 * side1) + (side3 * side3) == (side2 * side2)):
    print("Right-angled triangle")
else:
    print("Scalene triangle")

# %% [markdown]
# ### 10) WAP to find the second largest number among three user input numbers.

# %%
number1 = int(input("Enter first number: "))
number2 = int(input("Enter second number: "))
number3 = int(input("Enter third number: "))

if number1 > number2 > number3 or number3 > number2 > number1:
    print(number2)
elif number2 > number3 > number1 or number1 > number3 > number2:
    print(number3)
elif number3 > number1 > number2 or number2 > number1 > number3:
    print(number1)
# Out:
# Enter first number:  1
# Enter second number:  2
# Enter third number:  3
# 2

# %% [markdown]
# ### 11) WAP to calculate electricity bill based on following criteria. Which takes the unit from the user.
# a. First 1 to 50 units – Rs. 2.60/unit</br>
# b. Next 50 to 100 units – Rs. 3.25/unit</br>
# c. Next 100 to 200 units – Rs. 5.26/unit</br>
# d. above 200 units – Rs. 8.45/unit

# %%
units = int(input("Enter units: "))

if units < 0:
    print("Invalid input...")
elif 0 < units <= 50:
    totalBill = units * 2.60
elif 50 < units <= 100:
    totalBill = units * 3.25
elif 100 < units <= 200:
    totalBill = units * 2.60
elif units > 200:
    totalBill = units * 8.45

print("Total amount of " + str(units) + " units is: " + str(totalBill))
# Out:
# Enter units:  250
# Total amount of 250 units is: 2112.5
